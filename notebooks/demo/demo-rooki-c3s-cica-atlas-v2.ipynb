# %% [markdown]
# # Run workflow with c3s-cica-atlas v2 data
#
# **Rooki** calls climate data operations on the **rook** processing service.

# %%
import os
import time
os.environ['ROOK_URL'] = 'http://rook.dkrz.de/wps'

from rooki import rooki
from rooki import operators as ops

# %% [markdown]
# ## workflow: subset BERKELEY

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.tnn.BERKELEY.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan,feb,mar",
    area='0.,49.,10.,65',
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.196392059326172 secs

# %%
resp.download_urls()
# Out:
# ['http://rook7.cloud.dkrz.de:80/outputs/rook/d71aad8a-1943-11f0-8f18-fa163eb671ca/tnn_BERKELEY_no-expt_mon_20000101-20000301.nc']

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_pbhyx067/tnn_BERKELEY_no-expt_mon_20000101-20000301.nc.
# <xarray.Dataset> Size: 3kB
# Dimensions:    (lat: 16, bnds: 2, lon: 10, time: 3)
# Coordinates:
#   * lat        (lat) float64 128B 49.5 50.5 51.5 52.5 ... 61.5 62.5 63.5 64.5
#   * lon        (lon) float64 80B 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
#   * time       (time) datetime64[ns] 24B 2000-01-01 2000-02-01 2000-03-01
#     height2m   float64 8B ...
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds   (lat, bnds) float64 256B ...
#     lon_bnds   (lon, bnds) float64 160B ...
#     time_bnds  (time, bnds) datetime64[ns] 48B ...
#     tnn        (time, lat, lon) float32 2kB ...
#     crs        int32 4B ...
# Attributes: (12/26)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         180.0
#     geospatial_lon_resolution:  1.0
#     geospatial_lon_units:       degrees_east
#     date_created:               2024-12-12 10:08:44.733564+01:00
#     tracking_id:                096e17c6-eeb0-42c8-91c9-6e09660ab064
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset ERA5-Land

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.fd.ERA5-Land.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan,feb,mar",
    area='0.,49.,10.,65',
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.200074911117554 secs

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_l4a8gj71/fd_ERA5-Land_no-expt_mon_20000101-20000301.nc.
# <xarray.Dataset> Size: 198kB
# Dimensions:      (lat: 160, bnds: 2, lon: 100, time: 3)
# Coordinates:
#   * lat          (lat) float64 1kB 49.1 49.2 49.3 49.4 ... 64.7 64.8 64.9 65.0
#   * lon          (lon) float64 800B 0.01099 0.111 0.211 ... 9.712 9.812 9.912
#   * time         (time) datetime64[ns] 24B 2000-01-01 2000-02-01 2000-03-01
#     threshold0c  float64 8B ...
#     height2m     float64 8B ...
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds     (lat, bnds) float64 3kB ...
#     lon_bnds     (lon, bnds) float64 2kB ...
#     time_bnds    (time, bnds) datetime64[ns] 48B ...
#     fd           (time, lat, lon) float32 192kB ...
#     crs          int32 4B ...
# Attributes: (12/26)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         179.9719696044922
#     geospatial_lon_resolution:  0.100006103515625
#     geospatial_lon_units:       degrees_east
#     date_created:               2025-03-28 18:35:00.106779+01:00
#     tracking_id:                c03079d2-99ad-4e1c-8d22-3a427d1a5735
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset cmip5

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.tx35.CMIP5.historical.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan,feb,mar",
    area='0.,49.,10.,65',
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.178259372711182 secs

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_glrld65a/tx35_CMIP5_historical_mon_20000101-20000301.nc.
# <xarray.Dataset> Size: 36kB
# Dimensions:          (lat: 9, bnds: 2, lon: 5, time: 3, member: 44)
# Coordinates:
#   * lat              (lat) float64 72B 49.0 51.0 53.0 55.0 ... 61.0 63.0 65.0
#   * lon              (lon) float64 40B 1.0 3.0 5.0 7.0 9.0
#   * time             (time) datetime64[ns] 24B 2000-01-01 2000-02-01 2000-03-01
#     member_id        (member) <U33 6kB ...
#     gcm_institution  (member) <U12 2kB ...
#     gcm_model        (member) <U13 2kB ...
#     gcm_variant      (member) <U7 1kB ...
#     threshold35c     float64 8B ...
#     height2m         float64 8B ...
# Dimensions without coordinates: bnds, member
# Data variables:
#     lat_bnds         (lat, bnds) float64 144B ...
#     lon_bnds         (lon, bnds) float64 80B ...
#     time_bnds        (time, bnds) datetime64[ns] 48B ...
#     tx35             (member, time, lat, lon) float32 24kB ...
#     crs              int32 4B ...
# Attributes: (12/27)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         180.0
#     geospatial_lon_resolution:  2.0
#     geospatial_lon_units:       degrees_east
#     date_created:               2025-02-07 16:16:01.605948+01:00
#     tracking_id:                a7be9bff-4754-4fa3-94f9-ee8764ebc0d8
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset cmip6

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.fd.CMIP6.historical.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan,feb,mar",
    area='0.,49.,10.,65',
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.203067302703857 secs

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_7no6ir0s/fd_CMIP6_historical_mon_20000101-20000301.nc.
# <xarray.Dataset> Size: 60kB
# Dimensions:          (lat: 16, bnds: 2, lon: 10, time: 3, member: 26)
# Coordinates:
#   * lat              (lat) float64 128B 49.5 50.5 51.5 52.5 ... 62.5 63.5 64.5
#   * lon              (lon) float64 80B 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5
#   * time             (time) datetime64[ns] 24B 2000-01-01 2000-02-01 2000-03-01
#     member_id        (member) <U46 5kB ...
#     gcm_institution  (member) <U19 2kB ...
#     gcm_model        (member) <U17 2kB ...
#     gcm_variant      (member) <U8 832B ...
#     threshold0c      float64 8B ...
#     height2m         float64 8B ...
# Dimensions without coordinates: bnds, member
# Data variables:
#     lat_bnds         (lat, bnds) float64 256B ...
#     lon_bnds         (lon, bnds) float64 160B ...
#     time_bnds        (time, bnds) datetime64[ns] 48B ...
#     fd               (member, time, lat, lon) float32 50kB ...
#     crs              int32 4B ...
# Attributes: (12/27)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         180.0
#     geospatial_lon_resolution:  1.0
#     geospatial_lon_units:       degrees_east
#     date_created:               2024-12-06 00:28:58.765021+01:00
#     tracking_id:                b42e5c49-8bd8-40f1-a174-92d10878c64c
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset CERRA

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.psl.CERRA.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan,feb,mar",
    area='0.,49.,10.,65',
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.218292951583862 secs

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_u4obfiu6/psl_CERRA_no-expt_mon_20000101-20000301.nc.
# <xarray.Dataset> Size: 502kB
# Dimensions:    (lat: 256, bnds: 2, lon: 160, time: 3)
# Coordinates:
#   * lat        (lat) float64 2kB 49.03 49.09 49.16 49.22 ... 64.84 64.91 64.97
#   * lon        (lon) float64 1kB 0.03125 0.09375 0.1562 ... 9.844 9.906 9.969
#   * time       (time) datetime64[ns] 24B 2000-01-01 2000-02-01 2000-03-01
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds   (lat, bnds) float64 4kB ...
#     lon_bnds   (lon, bnds) float64 3kB ...
#     time_bnds  (time, bnds) datetime64[ns] 48B ...
#     psl        (time, lat, lon) float32 492kB ...
#     crs        int32 4B ...
# Attributes: (12/26)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         74.1875
#     geospatial_lon_resolution:  0.0625
#     geospatial_lon_units:       degrees_east
#     date_created:               2024-12-04 12:19:51.247949+01:00
#     tracking_id:                1ca5afcd-3c1d-404b-9172-472880ec75b1
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset cordex eur-11

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.fd.CORDEX-EUR-11.historical.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan",
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 33.415350914001465 secs

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink__faxn9eg/fd_CORDEX-EUR-11_historical_mon_20000101-20000101.nc.
# <xarray.Dataset> Size: 104MB
# Dimensions:          (lat: 408, bnds: 2, lon: 881, time: 1, member: 72)
# Coordinates:
#   * lat              (lat) float64 3kB 21.81 21.94 22.06 ... 72.44 72.56 72.69
#   * lon              (lon) float64 7kB -44.81 -44.69 -44.56 ... 65.06 65.19
#   * time             (time) datetime64[ns] 8B 2000-01-01
#     member_id        (member) <U60 17kB ...
#     gcm_institution  (member) <U12 3kB ...
#     gcm_model        (member) <U12 3kB ...
#     gcm_variant      (member) <U7 2kB ...
#     rcm_institution  (member) <U10 3kB ...
#     rcm_model        (member) <U17 5kB ...
#     rcm_variant      (member) <U3 864B ...
#     threshold0c      float64 8B ...
#     height2m         float64 8B ...
# Dimensions without coordinates: bnds, member
# Data variables:
#     lat_bnds         (lat, bnds) float64 7kB ...
#     lon_bnds         (lon, bnds) float64 14kB ...
#     time_bnds        (time, bnds) datetime64[ns] 16B ...
#     fd               (member, time, lat, lon) float32 104MB ...
#     crs              int32 4B ...
# Attributes: (12/27)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         65.25
#     geospatial_lon_resolution:  0.125
#     geospatial_lon_units:       degrees_east
#     date_created:               2024-12-09 16:29:21.678437+01:00
#     tracking_id:                875a8e49-a0e7-4475-b7fe-13f6f694e617
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset cordex core

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.rlds.CORDEX-CORE.historical.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan",
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 9.208575963973999 secs

# %%
resp.size_in_mb
# Out:
# 3.5153932571411133

# %%
resp.download_urls()
# Out:
# ['http://rook7.cloud.dkrz.de:80/outputs/rook/054798bc-1944-11f0-b4b2-fa163eb671ca/rlds_CORDEX-CORE_historical_mon_20000101-20000101.nc']

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_ymx1aewu/rlds_CORDEX-CORE_historical_mon_20000101-20000101.nc.
# <xarray.Dataset> Size: 37MB
# Dimensions:          (lat: 720, bnds: 2, lon: 1440, time: 1, member: 9)
# Coordinates:
#   * lat              (lat) float64 6kB -89.88 -89.62 -89.38 ... 89.62 89.88
#   * lon              (lon) float64 12kB -179.9 -179.6 -179.4 ... 179.6 179.9
#   * time             (time) datetime64[ns] 8B 2000-01-01
#     member_id        (member) <U26 936B ...
#     gcm_institution  (member) <U9 324B ...
#     gcm_model        (member) <U10 360B ...
# Dimensions without coordinates: bnds, member
# Data variables:
#     lat_bnds         (lat, bnds) float64 12kB ...
#     lon_bnds         (lon, bnds) float64 23kB ...
#     time_bnds        (time, bnds) datetime64[ns] 16B ...
#     rcm_model        (member) <U5 180B ...
#     rlds             (member, time, lat, lon) float32 37MB ...
#     crs              int32 4B ...
# Attributes: (12/29)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_units:       degrees_east
#     date_created:               2024-12-09 16:29:21.744026+01:00
#     tracking_id:                3a8f6b5d-ae95-4b75-9966-317cc06efaf4
#     member_provenance:          Values uniquely identify each member of the e...
#     reference:                  https://doi.org/10.1175/BAMS-D-22-0111.1
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: subset CPC

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.rx1day.CPC.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="2000/2000",
    time_components="month:jan",
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.237607955932617 secs

# %%
resp.size_in_mb
# Out:
# 0.22470951080322266

# %%
resp.download_urls()
# Out:
# ['http://rook7.cloud.dkrz.de:80/outputs/rook/09e420f2-1944-11f0-8672-fa163eb671ca/rx1day_CPC_no-expt_mon_20000101-20000101.nc']

# %%
ds = resp.datasets()[0]
ds
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_p6ya_xon/rx1day_CPC_no-expt_mon_20000101-20000101.nc.
# <xarray.Dataset> Size: 1MB
# Dimensions:    (lat: 360, bnds: 2, lon: 720, time: 1)
# Coordinates:
#   * lat        (lat) float64 3kB -89.75 -89.25 -88.75 ... 88.75 89.25 89.75
#   * lon        (lon) float64 6kB -179.8 -179.2 -178.8 ... 178.8 179.2 179.8
#   * time       (time) datetime64[ns] 8B 2000-01-01
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds   (lat, bnds) float64 6kB ...
#     lon_bnds   (lon, bnds) float64 12kB ...
#     time_bnds  (time, bnds) datetime64[ns] 16B ...
#     rx1day     (time, lat, lon) float32 1MB ...
#     crs        int32 4B ...
# Attributes: (12/26)
#     Conventions:                CF-1.9 ACDD-1.3
#     title:                      Copernicus Interactive Climate Atlas: gridded...
#     summary:                    Monthly/annual gridded data from observations...
#     institution:                Copernicus Climate Change Service (C3S)
#     producers:                  Institute of Physics of Cantabria (IFCA, CSIC...
#     license:                    CC-BY 4.0, https://creativecommons.org/licens...
#     ...                         ...
#     geospatial_lon_max:         180.0
#     geospatial_lon_resolution:  0.5
#     geospatial_lon_units:       degrees_east
#     date_created:               2025-02-19 11:37:31.953736+01:00
#     tracking_id:                3fd627f5-8b6e-48dd-84a2-0bb22eddd536
#     project_id:                 c3s-cica-atlas

# %% [markdown]
# ## workflow: complete time range

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.rlds.CORDEX-CORE.historical.mon.v2']
)

wf = ops.Subset(
    ds, 
    # time="2000/2000",
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 6.477520942687988 secs

# %%
resp.download_urls()
# Out:
# ['https://data.mips.climate.copernicus.eu/thredds/fileServer/esg_c3s-cica-atlas/v02/CORDEX-CORE/historical/rlds_CORDEX-CORE_historical_mon_197001-200512_v02.nc']

# %% [markdown]
# ## workflow: 10 years of time range

# %%
start = time.time()

# %%
ds = ops.Input(
    'ds', ['c3s-cica-atlas.rlds.CORDEX-CORE.historical.mon.v2']
)

wf = ops.Subset(
    ds, 
    time="1990/2000",
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %%
duration = time.time() - start
print(f"duration: {duration} secs")
# Out:
# duration: 72.74367213249207 secs

# %%
resp.size_in_mb
# Out:
# 445.2879333496094

# %%
resp.download_urls()
# Out:
# ['http://rook7.cloud.dkrz.de:80/outputs/rook/38183a80-1944-11f0-8338-fa163eb671ca/rlds_CORDEX-CORE_historical_mon_19900101-19940501.nc',
#  'http://rook7.cloud.dkrz.de:80/outputs/rook/38184ec6-1944-11f0-8338-fa163eb671ca/rlds_CORDEX-CORE_historical_mon_19940601-19981001.nc',
#  'http://rook7.cloud.dkrz.de:80/outputs/rook/38185c4a-1944-11f0-8338-fa163eb671ca/rlds_CORDEX-CORE_historical_mon_19981101-20001201.nc']
