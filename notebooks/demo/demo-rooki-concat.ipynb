# %% [markdown]
# # Examples for using concat operator on cmip6 decadal
#
# **Rooki** calls climate data operations on the **rook** processing service.

# %%
import os
os.environ['ROOK_URL'] = 'http://rook.dkrz.de/wps'

from rooki import operators as ops

# %% [markdown]
# ## Run concat

# %%
wf = ops.Concat(
        ops.Input(
                'tas', [
                    'c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dcppA-hindcast.s1995-r1i1p1f2.Amon.tas.gn.v20200417',
                    'c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dcppA-hindcast.s1995-r10i1p1f2.Amon.tas.gn.v20200417'
                ]
        ),
)

resp = wf.orchestrate()
resp.ok
# Out:
# True

# %% [markdown]
# **open with xarray**

# %%
dsets = resp.datasets()
# Out:
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_199511-199512.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_199601-199612.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_199701-199712.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_199801-199812.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_199901-199912.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200001-200012.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200101-200112.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200201-200212.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200301-200312.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200401-200412.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200501-200512.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r10i1p1f2_gn_200601-200603.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_199511-199512.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_199601-199612.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_199701-199712.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_199801-199812.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_199901-199912.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200001-200012.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200101-200112.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200201-200212.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200301-200312.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200401-200412.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200501-200512.nc.
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_rwam5816/tas_Amon_HadGEM3-GC31-MM_dcppA-hindcast_s1995-r1i1p1f2_gn_200601-200603.nc.

# %%
ds = dsets[0]
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 2, bnds: 2, lat: 324, lon: 432)
# Coordinates:
#   * time       (time) object 1995-11-16 00:00:00 1995-12-16 00:00:00
#   * lat        (lat) float64 -89.72 -89.17 -88.61 -88.06 ... 88.61 89.17 89.72
#   * lon        (lon) float64 0.4167 1.25 2.083 2.917 ... 357.1 357.9 358.7 359.6
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/43)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            DCPP
#     branch_method:          no parent
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     creation_date:          2020-05-26T09:34:24Z
#     ...                     ...
#     tracking_id:            hdl:21.14100/765ad328-6185-45a4-a49f-66277e6099b9
#     variable_id:            tas
#     variable_name:          tas
#     variant_label:          r10i1p1f2
#     license:                CMIP6 model data produced by Met Office Hadley Ce...
#     cmor_version:           3.4.0

# %% [markdown]
# **provenance**

# %%
prov_plot_url = resp.provenance_image()
prov_plot_url
# Out:
# 'http://rook4.cloud.dkrz.de:80/outputs/rook/d1681166-3ef8-11ed-a000-fa163ed6c06f/provenance.png'

# %%
#from IPython.display import Image
#Image(prov_plot_url)

# %%
resp.provenance()
# Out:
# 'http://rook4.cloud.dkrz.de:80/outputs/rook/d1681166-3ef8-11ed-a000-fa163ed6c06f/provenance.json'
