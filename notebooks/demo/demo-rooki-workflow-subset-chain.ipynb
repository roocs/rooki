# %% [markdown]
# # Run workfow with subset chain
#
# **Rooki** calls climate data operations on the **rook** processing service.

# %% [markdown]
# ## workflow with subset chain

# %%
import os
os.environ['ROOK_URL'] = 'http://cp4cds-cn2.cloud.dkrz.de/wps'

from rooki import operators as ops

# %%
wf = ops.Subset(
        ops.Subset(
            ops.Input(
                'rlds', ['CMIP6.CMIP.IPSL.IPSL-CM6A-LR.historical.r1i1p1f1.Amon.rlds.gr.v20180803']
            ),
            time="1860-01-01/1920-12-30",
        ),
        time="1880-01-01/1900-12-30",
)

# %%
resp = wf.orchestrate()
resp

# %% [markdown]
# **metalink output**

# %%
print(resp.xml)

# %% [markdown]
# **Size in MBytes**

# %%
resp.size_in_mb

# %% [markdown]
# **URLs in metalink document ...**

# %%
resp.download_urls()

# %% [markdown]
# **... and open with xarray**

# %%
ds = resp.datasets()[0]
ds

# %% [markdown]
# **provenance**

# %%
from IPython.display import Image
Image(resp.provenance_image())
