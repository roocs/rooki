# %% [markdown]
# # Demo for cmip6-decadal intake catalog

# %%
import intake

# %% [markdown]
# ## Open remote catalog

# %%
cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/master/intake/catalogs/c3s.yaml"

cat = intake.open_catalog(cat_url)
list(cat)
# Out:
# ['c3s-cmip5',
#  'c3s-cmip5-daily-pressure-level',
#  'c3s-cmip5-daily-single-level',
#  'c3s-cmip5-monthly-pressure-level',
#  'c3s-cmip5-monthly-single-level',
#  'c3s-cmip6',
#  'c3s-cmip6-r3',
#  'c3s-cmip6-decadal',
#  'c3s-cmip6-decadal-dwd',
#  'c3s-cordex',
#  'c3s-ipcc-atlas']

# %% [markdown]
# ## Load catalog for c3s-cmip6-decadal

# %%
df_cmip6_decadal = cat['c3s-cmip6-decadal'].read()
df_cmip6_decadal.head()
# Out:
#                                                ds_id  \
# 0  c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 1  c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 2  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 3  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 4  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
#
#                                                 path       size  \
# 0  DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2016-...  492479692
# 1  DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2009-...  737204109
# 2  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1987...     953384
# 3  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1995...     603757
# 4  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s2004...   14824913
#
#              mip_era activity_id institution_id        source_id  \
# 0  c3s-cmip6-decadal        DCPP          MPI-M    MPI-ESM1-2-HR
# 1  c3s-cmip6-decadal        DCPP          MPI-M    MPI-ESM1-2-HR
# 2  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 3  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 4  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
#
#     experiment_id        member_id table_id variable_id grid_label    version  \
# 0  dcppA-hindcast   s2016-r8i1p1f1      day      tasmax         gn  v20210111
# 1  dcppA-hindcast   s2009-r8i1p1f1      day          pr         gn  v20210107
# 2  dcppA-hindcast   s1987-r3i1p1f2     Amon          pr         gn  v20200417
# 3  dcppA-hindcast   s1995-r6i1p1f2     Amon         tas         gn  v20200417
# 4  dcppA-hindcast  s2004-r10i1p1f2   AERday       zg500         gn  v20200417
#
#             start_time             end_time                         bbox  \
# 0  2016-11-01T12:00:00  2026-12-31T12:00:00  0.00, -89.28, 359.06, 89.28
# 1  2009-11-01T12:00:00  2019-12-31T12:00:00  0.00, -89.28, 359.06, 89.28
# 2  1987-11-16T00:00:00  1987-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 3  1995-11-16T00:00:00  1995-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 4  2004-11-01T12:00:00  2004-12-30T12:00:00  0.42, -89.72, 359.58, 89.72
#
#       level member_year member_ensemble             prefix
# 0      2.00       s2016        r8i1p1f1  c3s-cmip6-decadal
# 1       NaN       s2009        r8i1p1f1  c3s-cmip6-decadal
# 2       NaN       s1987        r3i1p1f2  c3s-cmip6-decadal
# 3      1.50       s1995        r6i1p1f2  c3s-cmip6-decadal
# 4  50000.00       s2004       r10i1p1f2  c3s-cmip6-decadal

# %% [markdown]
# ## Check MOHC

# %%
institution_id = "MOHC"

df_inst = df_cmip6_decadal.loc[
    (df_cmip6_decadal.institution_id==institution_id)
]

df_inst.head()
# Out:
#                                                ds_id  \
# 2  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 3  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 4  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 5  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 7  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
#
#                                                 path      size  \
# 2  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1987...    953384
# 3  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1995...    603757
# 4  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s2004...  14824913
# 5  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1978...  16723575
# 7  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1970...    604054
#
#              mip_era activity_id institution_id        source_id  \
# 2  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 3  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 4  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 5  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 7  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
#
#     experiment_id        member_id table_id variable_id grid_label    version  \
# 2  dcppA-hindcast   s1987-r3i1p1f2     Amon          pr         gn  v20200417
# 3  dcppA-hindcast   s1995-r6i1p1f2     Amon         tas         gn  v20200417
# 4  dcppA-hindcast  s2004-r10i1p1f2   AERday       zg500         gn  v20200417
# 5  dcppA-hindcast   s1978-r9i1p1f2      day      tasmin         gn  v20200417
# 7  dcppA-hindcast   s1970-r6i1p1f2     Amon         tas         gn  v20200417
#
#             start_time             end_time                         bbox  \
# 2  1987-11-16T00:00:00  1987-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 3  1995-11-16T00:00:00  1995-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 4  2004-11-01T12:00:00  2004-12-30T12:00:00  0.42, -89.72, 359.58, 89.72
# 5  1978-11-01T12:00:00  1978-12-30T12:00:00  0.42, -89.72, 359.58, 89.72
# 7  1970-11-16T00:00:00  1970-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
#
#       level member_year member_ensemble             prefix
# 2       NaN       s1987        r3i1p1f2  c3s-cmip6-decadal
# 3      1.50       s1995        r6i1p1f2  c3s-cmip6-decadal
# 4  50000.00       s2004       r10i1p1f2  c3s-cmip6-decadal
# 5      1.50       s1978        r9i1p1f2  c3s-cmip6-decadal
# 7      1.50       s1970        r6i1p1f2  c3s-cmip6-decadal

# %%
member_years = list(set(df_inst.member_year))
member_years.sort()

for member_year in member_years:
    df = df_inst.loc[
        (df_inst.member_year==member_year)
    ]
    ensembles = list(set(df.member_ensemble))
    ensembles.sort()
    print(member_year, ensembles)
# Out:
# s1960 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1961 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1962 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1963 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1964 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1965 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1966 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1967 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1968 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1969 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1970 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1971 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1972 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1973 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1974 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1975 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1976 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1977 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1978 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1979 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1980 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1981 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1982 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1983 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1984 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1985 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1986 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1987 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1988 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1989 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1990 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1991 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1992 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1993 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1994 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1995 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1996 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1997 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1998 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s1999 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2000 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2001 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2002 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2003 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2004 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2005 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2006 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2007 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2008 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2009 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2010 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2011 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2012 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2013 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2014 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2015 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2016 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2017 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2018 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2019 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']
# s2020 ['r10i1p1f2', 'r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f2', 'r6i1p1f2', 'r7i1p1f2', 'r8i1p1f2', 'r9i1p1f2']

# %% [markdown]
# ## Check EC Earth

# %%
institution_id = "EC-Earth-Consortium"

df_inst = df_cmip6_decadal.loc[
    (df_cmip6_decadal.institution_id==institution_id)
]

df_inst.head()
# Out:
#                                                 ds_id  \
# 6   c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 11  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 17  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 22  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 29  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
#
#                                                  path     size  \
# 6   DCPP/EC-Earth-Consortium/EC-Earth3/dcppA-hindc...   848179
# 11  DCPP/EC-Earth-Consortium/EC-Earth3/dcppA-hindc...  4738074
# 17  DCPP/EC-Earth-Consortium/EC-Earth3/dcppA-hindc...  4730833
# 22  DCPP/EC-Earth-Consortium/EC-Earth3/dcppA-hindc...  4730873
# 29  DCPP/EC-Earth-Consortium/EC-Earth3/dcppA-hindc...  4729446
#
#               mip_era activity_id       institution_id  source_id  \
# 6   c3s-cmip6-decadal        DCPP  EC-Earth-Consortium  EC-Earth3
# 11  c3s-cmip6-decadal        DCPP  EC-Earth-Consortium  EC-Earth3
# 17  c3s-cmip6-decadal        DCPP  EC-Earth-Consortium  EC-Earth3
# 22  c3s-cmip6-decadal        DCPP  EC-Earth-Consortium  EC-Earth3
# 29  c3s-cmip6-decadal        DCPP  EC-Earth-Consortium  EC-Earth3
#
#      experiment_id       member_id table_id variable_id grid_label    version  \
# 6   dcppA-hindcast  s1995-r7i2p1f1     Amon         tas         gr  v20200508
# 11  dcppA-hindcast  s1995-r7i2p1f1     Amon         tas         gr  v20200508
# 17  dcppA-hindcast  s1995-r7i2p1f1     Amon         tas         gr  v20200508
# 22  dcppA-hindcast  s1995-r7i2p1f1     Amon         tas         gr  v20200508
# 29  dcppA-hindcast  s1995-r7i2p1f1     Amon         tas         gr  v20200508
#
#              start_time             end_time                         bbox  \
# 6   1995-11-16T00:00:00  1995-12-16T12:00:00  0.00, -89.46, 359.30, 89.46
# 11  1996-01-16T12:00:00  1996-12-16T12:00:00  0.00, -89.46, 359.30, 89.46
# 17  1997-01-16T12:00:00  1997-12-16T12:00:00  0.00, -89.46, 359.30, 89.46
# 22  1998-01-16T12:00:00  1998-12-16T12:00:00  0.00, -89.46, 359.30, 89.46
# 29  1999-01-16T12:00:00  1999-12-16T12:00:00  0.00, -89.46, 359.30, 89.46
#
#    level member_year member_ensemble             prefix
# 6   2.00       s1995        r7i2p1f1  c3s-cmip6-decadal
# 11  2.00       s1995        r7i2p1f1  c3s-cmip6-decadal
# 17  2.00       s1995        r7i2p1f1  c3s-cmip6-decadal
# 22  2.00       s1995        r7i2p1f1  c3s-cmip6-decadal
# 29  2.00       s1995        r7i2p1f1  c3s-cmip6-decadal

# %%
member_years = list(set(df_inst.member_year))
member_years.sort()

for member_year in member_years:
    df = df_inst.loc[
        (df_inst.member_year==member_year)
    ]
    ensembles = list(set(df.member_ensemble))
    ensembles.sort()
    print(member_year, ensembles)
# Out:
# s1960 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1961 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1962 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1963 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1964 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1965 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1966 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1967 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1968 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1969 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1970 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1971 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1972 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1973 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1974 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1975 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1976 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1977 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1978 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1979 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1980 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1981 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1982 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1983 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1984 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1985 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1986 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1987 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1988 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1989 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1990 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1991 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1992 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1993 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1994 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1995 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1996 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1997 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1998 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s1999 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2000 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2001 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2002 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2003 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2004 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2005 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2006 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2007 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2008 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2009 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2010 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2011 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2012 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2013 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2014 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2015 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2016 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2017 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2018 ['r10i1p1f1', 'r10i2p1f1', 'r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1', 'r8i2p1f1', 'r9i1p1f1', 'r9i2p1f1']
# s2019 ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r6i2p1f1', 'r7i1p1f1', 'r7i2p1f1', 'r8i1p1f1']
# s2020 ['r10i1p1f1', 'r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1', 'r4i1p1f1', 'r5i1p1f1', 'r6i1p1f1', 'r7i1p1f1', 'r8i1p1f1', 'r9i1p1f1']
