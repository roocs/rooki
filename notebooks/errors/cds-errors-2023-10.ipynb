# %% [markdown]
# ## Collected Errors reported by CDS 2023/10

# %%
import os
os.environ['ROOK_URL'] = 'http://rook.dkrz.de/wps'

from rooki import rooki

# %% [markdown]
# ## cmip6 dataset fails
#
# c3s-cmip6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.r1i1p1f2.Omon.tos.gn.v20190219
#
# We just got a user question about CMIP6. She wanted to download monthly, SSP3-7.0 data of sea surface temperature of the CNRM-CM6-1 model for the period 2016-2100.
# See below the API request. She asked for a subsetting but it has no significance here.
# Her request fails! I made some tests and it seems that model is available only until 2050 (all good to download data until 2049).
#
# Since the CDS user interface suggests the 2050-2100 period too, it gives the impression that the data are available, but this is not the case.
#
# It seems that the data is available until 2055 at the ESGF.

# %% [raw]
# import cdsapi
#
# c = cdsapi.Client()
#
# c.retrieve(
#
#     'projections-cmip6',
#
#     {
#
#         'temporal_resolution': 'monthly',
#
#         'experiment': 'ssp3_7_0',
#
#         'variable': 'sea_surface_temperature',
#
#         'model': 'cnrm_cm6_1',
#
#         'year': [
#
#             '2015', '2016', '2017',
#
#             '2018', '2019', '2020',
#
#             '2021', '2022', '2023',
#
#             '2024', '2025', '2026',
#
#             '2027', '2028', '2029',
#
#             '2030', '2031', '2032',
#
#             '2033', '2034', '2035',
#
#             '2036', '2037', '2038',
#
#             '2039', '2040', '2041',
#
#             '2042', '2043', '2044',
#
#             '2045', '2046', '2047',
#
#             '2048', '2049', '2050',
#
#             '2051', '2052', '2053',
#
#             '2054', '2055', '2056',
#
#             '2057', '2058', '2059',
#
#             '2060', '2061', '2062',
#
#             '2063', '2064', '2065',
#
#             '2066', '2067', '2068',
#
#             '2069', '2070', '2071',
#
#             '2072', '2073', '2074',
#
#             '2075', '2076', '2077',
#
#             '2078', '2079', '2080',
#
#             '2081', '2082', '2083',
#
#             '2084', '2085', '2086',
#
#             '2087', '2088', '2089',
#
#             '2090', '2091', '2092',
#
#             '2093', '2094', '2095',
#
#             '2096', '2097', '2098',
#
#             '2099',
#
#         ],
#
#         'month': [
#
#             '01', '02', '03',
#
#             '04', '05', '06',
#
#             '07', '08', '09',
#
#             '10', '11', '12',
#
#         ],
#
#         'area': [
#
#             42.8, 17.01, -31.3,
#
#             31.3,
#
#         ],
#
#         'format': 'zip',
#
#     },
#
#     'download.zip')

# %%
# C3S-CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1/ssp370/r1i1p1f2/Omon/tos/gn/v20190219/tos_Omon_CNRM-CM6-1_ssp370_r1i1p1f2_gn_201501-210012.nc

resp = rooki.subset(
    collection='c3s-cmip6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.r1i1p1f2.Omon.tos.gn.v20190219',
    # time='2016-01-01/2016-12-30',
)
resp.ok
# Out:
# True

# %%
resp.download_urls()
# Out:
# ['https://data.mips.copernicus-climate.eu/thredds/fileServer/esg_c3s-cmip6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1/ssp370/r1i1p1f2/Omon/tos/gn/v20190219/tos_Omon_CNRM-CM6-1_ssp370_r1i1p1f2_gn_201501-210012.nc']

# %%
resp = rooki.subset(
    collection='c3s-cmip6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.r1i1p1f2.Omon.tos.gn.v20190219',
    time='2050-01-01/2060-12-31',
)
resp.ok
# Out:
# True

# %%
resp.download_urls()
# Out:
# ['http://rook4.cloud.dkrz.de:80/outputs/rook/e7336a6a-71cc-11ee-9f1b-fa163ed6c06f/tos_Omon_CNRM-CM6-1_ssp370_r1i1p1f2_gn_20500116-20601216.nc']

# %%
resp = rooki.subset(
    collection='c3s-cmip6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.r1i1p1f2.Omon.tos.gn.v20190219',
    time='2050/2100',
    time_components="month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec",
    area='42.8, 17.01, -31.3, 31.3',
)
resp.ok
# Out:
# True

# %%
resp.download_urls()
# Out:
# ['http://rook4.cloud.dkrz.de:80/outputs/rook/ec5c86c0-71cc-11ee-80da-fa163ed6c06f/tos_Omon_CNRM-CM6-1_ssp370_r1i1p1f2_gn_20500116-21001216.nc']

# %%
dsets = resp.datasets()

# %%
dsets[0]
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 15, x: 73, nvertex: 4, time: 612, axis_nbounds: 2)
# Coordinates:
#     lat          (y, x) float64 ...
#     lon          (y, x) float64 ...
#   * time         (time) datetime64[ns] 2050-01-16T12:00:00 ... 2100-12-16T12:...
# Dimensions without coordinates: y, x, nvertex, axis_nbounds
# Data variables:
#     bounds_lon   (y, x, nvertex) float64 ...
#     bounds_lat   (y, x, nvertex) float64 ...
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     tos          (time, y, x) float32 ...
# Attributes: (12/52)
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-11-15T10:44:43Z
#     description:            Future scenario with high radiative forcing by th...
#     title:                  CNRM-CM6-1 model output prepared for CMIP6 / Scen...
#     activity_id:            ScenarioMIP AerChemMIP
#     contact:                contact.cmip@meteo.fr
#     ...                     ...
# ...

# %%
min_lat = float(dsets[0].lat.min())
max_lat = float(dsets[0].lat.max())
min_lon = float(dsets[0].lon.min())
max_lon = float(dsets[0].lon.max())

print(f"min lat={min_lat}, max lat={max_lat}, min lon={min_lon}, max lon={max_lon}")
# Out:
# min lat=17.715097427368164, max lat=30.474071502685547, min lon=-30.501068115234375, max lon=41.51707458496094
