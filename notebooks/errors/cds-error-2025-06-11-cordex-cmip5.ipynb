# %% [markdown]
# # Issues with CORDEX-CMIP5
#
# List of issues with the CORDEX-CMIP5 data from the CDS.
#
# Some questions:
# * Should someone create an Errata entry about [1] and [4]?
# * Are [2] and [3] due to an issue with the C3S copy or manifest file, or is the data simply not available?
# * Is [7] only corrupted in the C3S copy, or also in the original?
#
#
# ## [1] (extension of original report)
#
# * eur11-hist-day-ichec_ec_earth-clmcom_clm_cclm4_8_17-r12i1p1
# * eur11-hist-day-mohc_hadgem2_es-clmcom_clm_cclm4_8_17-r1i1p1
# * eur11-hist-day-mpi_m_mpi_esm_lr-clmcom_clm_cclm4_8_17-r1i1p1
# * eur11-rcp45-day-ichec_ec_earth-clmcom_clm_cclm4_8_17-r12i1p1
# * eur11-rcp45-day-mohc_hadgem2_es-clmcom_clm_cclm4_8_17-r1i1p1
# * eur11-rcp45-day-mpi_m_mpi_esm_lr-clmcom_clm_cclm4_8_17-r1i1p1
# * eur11-rcp85-day-ichec_ec_earth-clmcom_clm_cclm4_8_17-r12i1p1
# * eur11-rcp85-day-mohc_hadgem2_es-clmcom_clm_cclm4_8_17-r1i1p1
# * eur11-rcp85-day-mpi_m_mpi_esm_lr-clmcom_clm_cclm4_8_17-r1i1p1
#
# They all share the same regional model, CLMcom-CLM-CCLM4-8-17, and with different realisations: r12i1p1, r1i1p1. The anomaly occurs in the following variables: clt, rlds, ps, rsus, which show extremely high and low values.
#
# ## [2]
#
# * eur11-hist-day-mohc_hadgem2_es-knmi_racmo22e-r1i1p1
#
# Missing rlds variable (surface downwelling longwave flux) data for 1981-1985.
#
# ## [3]
#
# * eur11-rcp85-day-ichec_ec_earth-dmi_hirham5-r3i1p1
#
# Missing huss (specific humidity) data for 1971-1975.
#
# ## [4]
#
# * eur11-rcp85-day-ichec_ec_earth-uhoh_wrf361h-r12i1p1
# * eur11-rcp85-day-mohc_hadgem2_es-uhoh_wrf361h-r1i1p1
# * eur11-rcp85-day-mpi_m_mpi_esm_lr-uhoh_wrf361h-r1i1p1
#
# Very large values for several dates in huss, ps.
#
# ## [5]
#
# * eur11-hist-day-mpi_m_mpi_esm_lr-ipsl_wrf381p-r1i1p1
# * eur11-rcp85-day-mpi_m_mpi_esm_lr-ipsl_wrf381p-r1i1p1
#
# Invalid x, y coordinates: all 0’s
#
# ## [6]
#
# * eur11-hist-day-miroc_miroc5-uhoh_wrf361h-r1i1p1
#
# Missing projection information at least for rsds and the 1970 file, maybe also in other variables/files.
#
# Similarly:
#
# *   eur11-rcp85-day-miroc_miroc5-uhoh_wrf361h-r1i1p1
#
# Missing projection information at least _ for _huss and the 2006-2010 file, maybe also in other variables/files.
#
# ## [7]
#
# * eur11-hist-6h-mohc_hadgem2_es-cnrm_aladin63-r1i1p1
#
# Data for mrro seems corrupted for at least the 1950 file ("NetCDF: HDF error" thrown when reading daily sample #60 (0-based))

# %% [markdown]
# ## Init rooki

# %%
import os
os.environ['ROOK_URL'] = 'http://rook.dkrz.de/wps'

from rooki import rooki

# %% [markdown]
# ## Load catalog

# %%
import intake

# %%
cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/master/intake/catalogs/c3s.yaml"

cat = intake.open_catalog(cat_url)
list(cat)
# Out:
# ['c3s-cmip5',
#  'c3s-cmip5-daily-pressure-level',
#  'c3s-cmip5-daily-single-level',
#  'c3s-cmip5-monthly-pressure-level',
#  'c3s-cmip5-monthly-single-level',
#  'c3s-cmip6',
#  'c3s-cmip6-decadal',
#  'c3s-cordex',
#  'c3s-ipcc-atlas',
#  'c3s-cica-atlas-v01',
#  'c3s-cica-atlas']

# %%
df_cordex = cat['c3s-cordex'].read()
df_cordex
# Out:
#                                                     ds_id  \
# 0       c3s-cordex.output.EAS-44.CLMcom.CNRM-CERFACS-C...
# 1       c3s-cordex.output.EAS-44.CLMcom.CNRM-CERFACS-C...
# 2       c3s-cordex.output.EAS-44.CLMcom.CNRM-CERFACS-C...
# 3       c3s-cordex.output.EAS-44.CLMcom.CNRM-CERFACS-C...
# 4       c3s-cordex.output.EAS-44.CLMcom.CNRM-CERFACS-C...
# ...                                                   ...
# 567374  c3s-cordex.output.CAM-44.SMHI.ICHEC-EC-EARTH.h...
# 567375  c3s-cordex.output.CAM-44.SMHI.ICHEC-EC-EARTH.h...
# 567376  c3s-cordex.output.CAM-44.SMHI.ICHEC-EC-EARTH.h...
# 567377  c3s-cordex.output.CAM-44.SMHI.ICHEC-EC-EARTH.h...
# 567378  c3s-cordex.output.CAM-44.SMHI.ICHEC-EC-EARTH.h...
#
#                                                      path       size  \
# 0       output/EAS-44/CLMcom/CNRM-CERFACS-CNRM-CM5/rcp...  176452637
# 1       output/EAS-44/CLMcom/CNRM-CERFACS-CNRM-CM5/rcp...  176393262
# 2       output/EAS-44/CLMcom/CNRM-CERFACS-CNRM-CM5/rcp...  176557045
# 3       output/EAS-44/CLMcom/CNRM-CERFACS-CNRM-CM5/rcp...  176346476
# 4       output/EAS-44/CLMcom/CNRM-CERFACS-CNRM-CM5/rcp...  176260737
# ...                                                   ...        ...
# 567374  output/CAM-44/SMHI/ICHEC-EC-EARTH/historical/r...   60776141
# 567375  output/CAM-44/SMHI/ICHEC-EC-EARTH/historical/r...   60562273
# 567376  output/CAM-44/SMHI/ICHEC-EC-EARTH/historical/r...   60779301
# 567377  output/CAM-44/SMHI/ICHEC-EC-EARTH/historical/r...   60957749
# 567378  output/CAM-44/SMHI/ICHEC-EC-EARTH/historical/r...   60801923
#
#            project product  domain institute          driving_model  \
# 0       c3s-cordex  output  EAS-44    CLMcom  CNRM-CERFACS-CNRM-CM5
# 1       c3s-cordex  output  EAS-44    CLMcom  CNRM-CERFACS-CNRM-CM5
# 2       c3s-cordex  output  EAS-44    CLMcom  CNRM-CERFACS-CNRM-CM5
# 3       c3s-cordex  output  EAS-44    CLMcom  CNRM-CERFACS-CNRM-CM5
# 4       c3s-cordex  output  EAS-44    CLMcom  CNRM-CERFACS-CNRM-CM5
# ...            ...     ...     ...       ...                    ...
# 567374  c3s-cordex  output  CAM-44      SMHI         ICHEC-EC-EARTH
# 567375  c3s-cordex  output  CAM-44      SMHI         ICHEC-EC-EARTH
# 567376  c3s-cordex  output  CAM-44      SMHI         ICHEC-EC-EARTH
# 567377  c3s-cordex  output  CAM-44      SMHI         ICHEC-EC-EARTH
# 567378  c3s-cordex  output  CAM-44      SMHI         ICHEC-EC-EARTH
#
#        experiment_id ensemble          rcm_name rcm_version time_frequency  \
# 0              rcp45   r1i1p1  CLMcom-CCLM5-0-2          v1            day
# 1              rcp45   r1i1p1  CLMcom-CCLM5-0-2          v1            day
# 2              rcp45   r1i1p1  CLMcom-CCLM5-0-2          v1            day
# 3              rcp45   r1i1p1  CLMcom-CCLM5-0-2          v1            day
# 4              rcp45   r1i1p1  CLMcom-CCLM5-0-2          v1            day
# ...              ...      ...               ...         ...            ...
# 567374    historical  r12i1p1         SMHI-RCA4          v1            day
# 567375    historical  r12i1p1         SMHI-RCA4          v1            day
# 567376    historical  r12i1p1         SMHI-RCA4          v1            day
# 567377    historical  r12i1p1         SMHI-RCA4          v1            day
# 567378    historical  r12i1p1         SMHI-RCA4          v1            day
#
#        variable    version           start_time             end_time  \
# 0          huss  v20201215  2006-01-01T12:00:00  2010-12-31T12:00:00
# 1          huss  v20201215  2011-01-01T12:00:00  2015-12-31T12:00:00
# 2          huss  v20201215  2016-01-01T12:00:00  2020-12-31T12:00:00
# 3          huss  v20201215  2021-01-01T12:00:00  2025-12-31T12:00:00
# 4          huss  v20201215  2026-01-01T12:00:00  2030-12-31T12:00:00
# ...         ...        ...                  ...                  ...
# 567374   tasmin  v20201201  1981-01-01T12:00:00  1985-12-31T12:00:00
# 567375   tasmin  v20201201  1986-01-01T12:00:00  1990-12-31T12:00:00
# 567376   tasmin  v20201201  1991-01-01T12:00:00  1995-12-31T12:00:00
# 567377   tasmin  v20201201  1996-01-01T12:00:00  2000-12-31T12:00:00
# 567378   tasmin  v20201201  2001-01-01T12:00:00  2005-12-31T12:00:00
#
#                                   bbox  level
# 0         63.36, -18.23, 175.13, 58.59  10.00
# 1         63.36, -18.23, 175.13, 58.59  10.00
# 2         63.36, -18.23, 175.13, 58.59  10.00
# 3         63.36, -18.23, 175.13, 58.59  10.00
# 4         63.36, -18.23, 175.13, 58.59  10.00
# ...                                ...    ...
# 567374  -127.58, -19.46, -19.41, 46.38   2.00
# 567375  -127.58, -19.46, -19.41, 46.38   2.00
# 567376  -127.58, -19.46, -19.41, 46.38   2.00
# 567377  -127.58, -19.46, -19.41, 46.38   2.00
# 567378  -127.58, -19.46, -19.41, 46.38   2.00
#
# [567379 rows x 19 columns]

# %% [markdown]
# ## Issue [2]
#
# eur11-hist-day-mohc_hadgem2_es-knmi_racmo22e-r1i1p1
#
# Missing rlds variable (surface downwelling longwave flux) data for 1981-1985.

# %%
# [2] eur11-hist-day-mohc_hadgem2_es-knmi_racmo22e-r1i1p1

df_2 = df_cordex.loc[
    (df_cordex.variable=="rlds") 
    & (df_cordex.experiment_id=="historical")
    & (df_cordex.rcm_name=="KNMI-RACMO22E")
    & (df_cordex.domain=="EUR-11")
    & (df_cordex.time_frequency=="day")
    & (df_cordex.driving_model=="MOHC-HadGEM2-ES")
    & (df_cordex.ensemble=="r1i1p1")
]
df_2.head()
# Out:
#                                                     ds_id  \
# 327837  c3s-cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES....
# 327838  c3s-cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES....
# 327839  c3s-cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES....
# 327840  c3s-cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES....
# 327841  c3s-cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES....
#
#                                                      path       size  \
# 327837  output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/...  154588846
# 327838  output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/...  766117778
# 327839  output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/...  765334038
# 327840  output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/...  766504656
# 327841  output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/...  765524191
#
#            project product  domain institute    driving_model experiment_id  \
# 327837  c3s-cordex  output  EUR-11      KNMI  MOHC-HadGEM2-ES    historical
# 327838  c3s-cordex  output  EUR-11      KNMI  MOHC-HadGEM2-ES    historical
# 327839  c3s-cordex  output  EUR-11      KNMI  MOHC-HadGEM2-ES    historical
# 327840  c3s-cordex  output  EUR-11      KNMI  MOHC-HadGEM2-ES    historical
# 327841  c3s-cordex  output  EUR-11      KNMI  MOHC-HadGEM2-ES    historical
#
#        ensemble       rcm_name rcm_version time_frequency variable    version  \
# 327837   r1i1p1  KNMI-RACMO22E          v2            day     rlds  v20160620
# 327838   r1i1p1  KNMI-RACMO22E          v2            day     rlds  v20160620
# 327839   r1i1p1  KNMI-RACMO22E          v2            day     rlds  v20160620
# 327840   r1i1p1  KNMI-RACMO22E          v2            day     rlds  v20160620
# 327841   r1i1p1  KNMI-RACMO22E          v2            day     rlds  v20160620
#
#                  start_time             end_time                         bbox  \
# 327837  1950-01-01T12:00:00  1950-12-30T12:00:00  -44.59, 21.99, 64.96, 72.58
# 327838  1951-01-01T12:00:00  1955-12-30T12:00:00  -44.59, 21.99, 64.96, 72.58
# 327839  1956-01-01T12:00:00  1960-12-30T12:00:00  -44.59, 21.99, 64.96, 72.58
# 327840  1961-01-01T12:00:00  1965-12-30T12:00:00  -44.59, 21.99, 64.96, 72.58
# 327841  1966-01-01T12:00:00  1970-12-30T12:00:00  -44.59, 21.99, 64.96, 72.58
#
#        level
# 327837   NaN
# 327838   NaN
# 327839   NaN
# 327840   NaN
# 327841   NaN

# %%
start_time = list(df_2.start_time.unique())
start_time.sort()
start_time
# Out:
# ['1950-01-01T12:00:00',
#  '1951-01-01T12:00:00',
#  '1956-01-01T12:00:00',
#  '1961-01-01T12:00:00',
#  '1966-01-01T12:00:00',
#  '1971-01-01T12:00:00',
#  '1976-01-01T12:00:00',
#  '1986-01-01T12:00:00',
#  '1991-01-01T12:00:00',
#  '1996-01-01T12:00:00',
#  '2001-01-01T12:00:00']

# %%
end_time = list(df_2.end_time.unique())
end_time.sort()
end_time
# Out:
# ['1950-12-30T12:00:00',
#  '1955-12-30T12:00:00',
#  '1960-12-30T12:00:00',
#  '1965-12-30T12:00:00',
#  '1970-12-30T12:00:00',
#  '1975-12-30T12:00:00',
#  '1980-12-30T12:00:00',
#  '1990-12-30T12:00:00',
#  '1995-12-30T12:00:00',
#  '2000-12-30T12:00:00',
#  '2005-12-30T12:00:00']

# %%
list(df_2.rcm_name.unique())
# Out:
# ['KNMI-RACMO22E']

# %%
list(df_2.path.unique())
# Out:
# ['output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19500101-19501230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19510101-19551230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19560101-19601230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19610101-19651230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19660101-19701230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19710101-19751230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19760101-19801230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19860101-19901230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19910101-19951230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19960101-20001230.nc',
#  'output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620/rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_20010101-20051230.nc']

# %% [markdown]
# ### check on disk
#
# ```
# ls -l output/EUR-11/KNMI/MOHC-HadGEM2-ES/historical/r1i1p1/KNMI-RACMO22E/v2/day/rlds/v20160620
# total 7633768
# -rw-r--r--. 1  154588846 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19500101-19501230.nc
# -rw-r--r--. 1  766117778 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19510101-19551230.nc
# -rw-r--r--. 1  765334038 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19560101-19601230.nc
# -rw-r--r--. 1  766504656 Jan 26  2020 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19610101-19651230.nc
# -rw-r--r--. 1  765524191 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19660101-19701230.nc
# -rw-r--r--. 1  766009746 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19710101-19751230.nc
# -rw-r--r--. 1  764979219 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19760101-19801230.nc
# -rw-r--r--. 1   8388608 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19810101-19851230.nc
# -rw-r--r--. 1  764348850 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19860101-19901230.nc
# -rw-r--r--. 1  766102908 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19910101-19951230.nc
# -rw-r--r--. 1  763787382 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_19960101-20001230.nc
# -rw-r--r--. 1  765224568 Sep 13  2021 rlds_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_KNMI-RACMO22E_v2_day_20010101-20051230.nc
#     ```

# %% [markdown]
# ## Issue [3]
#
# * eur11-rcp85-day-ichec_ec_earth-dmi_hirham5-r3i1p1
#
# Missing huss (specific humidity) data for 1971-1975.

# %%
# [2] eur11-rcp85-day-ichec_ec_earth-dmi_hirham5-r3i1p1

df_3 = df_cordex.loc[
    (df_cordex.variable=="huss") 
    # & (df_cordex.experiment_id=="historical")
    & (df_cordex.experiment_id=="rcp85")
    # & (df_cordex.institute=="MOHC")
    & (df_cordex.domain=="EUR-11")
    & (df_cordex.time_frequency=="day")
    & (df_cordex.driving_model=="ICHEC-EC-EARTH")
    & (df_cordex.rcm_name=="DMI-HIRHAM5")
    & (df_cordex.ensemble=="r3i1p1")
]
df_3.head()
# Out:
#                                                     ds_id  \
# 488871  c3s-cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rc...
# 488879  c3s-cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rc...
# 488887  c3s-cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rc...
# 488895  c3s-cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rc...
# 488903  c3s-cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rc...
#
#                                                      path       size  \
# 488871  output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/...  521448501
# 488879  output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/...  519714644
# 488887  output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/...  520281348
# 488895  output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/...  519474980
# 488903  output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/...  518582540
#
#            project product  domain institute   driving_model experiment_id  \
# 488871  c3s-cordex  output  EUR-11       DMI  ICHEC-EC-EARTH         rcp85
# 488879  c3s-cordex  output  EUR-11       DMI  ICHEC-EC-EARTH         rcp85
# 488887  c3s-cordex  output  EUR-11       DMI  ICHEC-EC-EARTH         rcp85
# 488895  c3s-cordex  output  EUR-11       DMI  ICHEC-EC-EARTH         rcp85
# 488903  c3s-cordex  output  EUR-11       DMI  ICHEC-EC-EARTH         rcp85
#
#        ensemble     rcm_name rcm_version time_frequency variable    version  \
# 488871   r3i1p1  DMI-HIRHAM5          v2            day     huss  v20190212
# 488879   r3i1p1  DMI-HIRHAM5          v2            day     huss  v20190212
# 488887   r3i1p1  DMI-HIRHAM5          v2            day     huss  v20190212
# 488895   r3i1p1  DMI-HIRHAM5          v2            day     huss  v20190212
# 488903   r3i1p1  DMI-HIRHAM5          v2            day     huss  v20190212
#
#                  start_time             end_time                         bbox  \
# 488871  2036-01-01T12:00:00  2040-12-31T12:00:00  -44.59, 21.99, 64.96, 72.58
# 488879  2041-01-01T12:00:00  2045-12-31T12:00:00  -44.59, 21.99, 64.96, 72.58
# 488887  2046-01-01T12:00:00  2050-12-31T12:00:00  -44.59, 21.99, 64.96, 72.58
# 488895  2051-01-01T12:00:00  2055-12-31T12:00:00  -44.59, 21.99, 64.96, 72.58
# 488903  2056-01-01T12:00:00  2060-12-31T12:00:00  -44.59, 21.99, 64.96, 72.58
#
#        level
# 488871  2.00
# 488879  2.00
# 488887  2.00
# 488895  2.00
# 488903  2.00

# %%
start_time = list(df_3.start_time.unique())
start_time.sort()
start_time
# Out:
# ['2006-01-01T12:00:00',
#  '2011-01-01T12:00:00',
#  '2016-01-01T12:00:00',
#  '2021-01-01T12:00:00',
#  '2026-01-01T12:00:00',
#  '2031-01-01T12:00:00',
#  '2036-01-01T12:00:00',
#  '2041-01-01T12:00:00',
#  '2046-01-01T12:00:00',
#  '2051-01-01T12:00:00',
#  '2056-01-01T12:00:00',
#  '2061-01-01T12:00:00',
#  '2066-01-01T12:00:00',
#  '2076-01-01T12:00:00',
#  '2081-01-01T12:00:00',
#  '2086-01-01T12:00:00',
#  '2091-01-01T12:00:00',
#  '2096-01-01T12:00:00']

# %%
end_time = list(df_3.end_time.unique())
end_time.sort()
end_time
# Out:
# ['2010-12-31T12:00:00',
#  '2015-12-31T12:00:00',
#  '2020-12-31T12:00:00',
#  '2025-12-31T12:00:00',
#  '2030-12-31T12:00:00',
#  '2035-12-31T12:00:00',
#  '2040-12-31T12:00:00',
#  '2045-12-31T12:00:00',
#  '2050-12-31T12:00:00',
#  '2055-12-31T12:00:00',
#  '2060-12-31T12:00:00',
#  '2065-12-31T12:00:00',
#  '2070-12-31T12:00:00',
#  '2080-12-31T12:00:00',
#  '2085-12-31T12:00:00',
#  '2090-12-31T12:00:00',
#  '2095-12-31T12:00:00',
#  '2100-12-31T12:00:00']

# %%
list(df_3.path.unique())
# Out:
# ['output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20360101-20401231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20410101-20451231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20460101-20501231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20510101-20551231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20560101-20601231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20610101-20651231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20660101-20701231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20060101-20101231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20110101-20151231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20160101-20201231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20210101-20251231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20260101-20301231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20310101-20351231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20760101-20801231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20810101-20851231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20860101-20901231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20910101-20951231.nc',
#  'output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212/huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20960101-21001231.nc']

# %% [markdown]
# ### check on disk
#
# ```
# ls -l output/EUR-11/DMI/ICHEC-EC-EARTH/rcp85/r3i1p1/DMI-HIRHAM5/v2/day/huss/v20190212
# total 9124048
# -rw-r--r--. 1  516902199 Jan 16  2020 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20060101-20101231.nc
# -rw-r--r--. 1  520315924 Sep  8  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20110101-20151231.nc
# -rw-r--r--. 1  520898405 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20160101-20201231.nc
# -rw-r--r--. 1  518106159 Jan 16  2020 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20210101-20251231.nc
# -rw-r--r--. 1  522595279 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20260101-20301231.nc
# -rw-r--r--. 1  518888064 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20310101-20351231.nc
# -rw-r--r--. 1  521448501 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20360101-20401231.nc
# -rw-r--r--. 1  519714644 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20410101-20451231.nc
# -rw-r--r--. 1  520281348 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20460101-20501231.nc
# -rw-r--r--. 1  519474980 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20510101-20551231.nc
# -rw-r--r--. 1  518582540 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20560101-20601231.nc
# -rw-r--r--. 1  518899207 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20610101-20651231.nc
# -rw-r--r--. 1  518216922 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20660101-20701231.nc
# -rw-r--r--. 1          0 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20710101-20751231.nc
# -rw-r--r--. 1  517869683 Jan 16  2020 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20760101-20801231.nc
# -rw-r--r--. 1  518097668 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20810101-20851231.nc
# -rw-r--r--. 1  515592515 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20860101-20901231.nc
# -rw-r--r--. 1  517965982 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20910101-20951231.nc
# -rw-r--r--. 1  519067104 Sep  9  2021 huss_EUR-11_ICHEC-EC-EARTH_rcp85_r3i1p1_DMI-HIRHAM5_v2_day_20960101-21001231.nc
# ```

# %% [markdown]
# ## [7]
#
# * eur11-hist-6h-mohc_hadgem2_es-cnrm_aladin63-r1i1p1
#
# Data for mrro seems corrupted for at least the 1950 file ("NetCDF: HDF error" thrown when reading daily sample #60 (0-based))

# %%
df_7 = df_cordex.loc[
    (df_cordex.variable=="mrro") 
    & (df_cordex.experiment_id=="historical")
    & (df_cordex.institute=="MOHC")
    & (df_cordex.domain=="EUR-11")
    & (df_cordex.time_frequency=="6hr")
    & (df_cordex.driving_model=="MOHC-HadGEM2-ES")
    & (df_cordex.ensemble=="r1i1p1")
]
df_7.head()
# Out:
#                                                   ds_id  \
# 9169  c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES....
# 9170  c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES....
# 9171  c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES....
# 9172  c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES....
# 9173  c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES....
#
#                                                    path       size  \
# 9169  output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/...   25431205
# 9170  output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/...  207610957
# 9171  output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/...  205001855
# 9172  output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/...  207068685
# 9173  output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/...  209834033
#
#          project product  domain institute    driving_model experiment_id  \
# 9169  c3s-cordex  output  EUR-11      MOHC  MOHC-HadGEM2-ES    historical
# 9170  c3s-cordex  output  EUR-11      MOHC  MOHC-HadGEM2-ES    historical
# 9171  c3s-cordex  output  EUR-11      MOHC  MOHC-HadGEM2-ES    historical
# 9172  c3s-cordex  output  EUR-11      MOHC  MOHC-HadGEM2-ES    historical
# 9173  c3s-cordex  output  EUR-11      MOHC  MOHC-HadGEM2-ES    historical
#
#      ensemble             rcm_name rcm_version time_frequency variable  \
# 9169   r1i1p1  MOHC-HadREM3-GA7-05          v1            6hr     mrro
# 9170   r1i1p1  MOHC-HadREM3-GA7-05          v1            6hr     mrro
# 9171   r1i1p1  MOHC-HadREM3-GA7-05          v1            6hr     mrro
# 9172   r1i1p1  MOHC-HadREM3-GA7-05          v1            6hr     mrro
# 9173   r1i1p1  MOHC-HadREM3-GA7-05          v1            6hr     mrro
#
#         version           start_time             end_time  \
# 9169  v20200330  1951-12-01T03:00:00  1951-12-30T21:00:00
# 9170  v20200330  1952-01-01T03:00:00  1952-12-30T21:00:00
# 9171  v20200330  1953-01-01T03:00:00  1953-12-30T21:00:00
# 9172  v20200330  1954-01-01T03:00:00  1954-12-30T21:00:00
# 9173  v20200330  1955-01-01T03:00:00  1955-12-30T21:00:00
#
#                              bbox level
# 9169  -44.59, 21.99, 64.96, 72.59   NaN
# 9170  -44.59, 21.99, 64.96, 72.59   NaN
# 9171  -44.59, 21.99, 64.96, 72.59   NaN
# 9172  -44.59, 21.99, 64.96, 72.59   NaN
# 9173  -44.59, 21.99, 64.96, 72.59   NaN

# %%
list(df_7.ds_id.unique())
# Out:
# ['c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1.MOHC-HadREM3-GA7-05.v1.6hr.mrro.v20200330']

# %%
ds_id_7 = list(df_7.ds_id.unique())[0]
ds_id_7
# Out:
# 'c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1.MOHC-HadREM3-GA7-05.v1.6hr.mrro.v20200330'

# %%
start_time = list(df_7.start_time.unique())
start_time.sort()
start_time
# Out:
# ['1951-12-01T03:00:00',
#  '1952-01-01T03:00:00',
#  '1953-01-01T03:00:00',
#  '1954-01-01T03:00:00',
#  '1955-01-01T03:00:00',
#  '1956-01-01T03:00:00',
#  '1957-01-01T03:00:00',
#  '1958-01-01T03:00:00',
#  '1959-01-01T03:00:00',
#  '1960-01-01T03:00:00',
#  '1961-01-01T03:00:00',
#  '1962-01-01T03:00:00',
#  '1963-01-01T03:00:00',
#  '1964-01-01T03:00:00',
#  '1965-01-01T03:00:00',
#  '1966-01-01T03:00:00',
#  '1967-01-01T03:00:00',
#  '1968-01-01T03:00:00',
#  '1969-01-01T03:00:00',
#  '1970-01-01T03:00:00',
#  '1971-01-01T03:00:00',
#  '1972-01-01T03:00:00',
#  '1973-01-01T03:00:00',
#  '1974-01-01T03:00:00',
#  '1975-01-01T03:00:00',
#  '1976-01-01T03:00:00',
#  '1977-01-01T03:00:00',
#  '1978-01-01T03:00:00',
#  '1979-01-01T03:00:00',
#  '1980-01-01T03:00:00',
#  '1981-01-01T03:00:00',
#  '1982-01-01T03:00:00',
#  '1983-01-01T03:00:00',
#  '1984-01-01T03:00:00',
#  '1985-01-01T03:00:00',
#  '1986-01-01T03:00:00',
#  '1987-01-01T03:00:00',
#  '1988-01-01T03:00:00',
#  '1989-01-01T03:00:00',
#  '1990-01-01T03:00:00',
#  '1991-01-01T03:00:00',
#  '1992-01-01T03:00:00',
#  '1993-01-01T03:00:00',
#  '1994-01-01T03:00:00',
#  '1995-01-01T03:00:00',
#  '1996-01-01T03:00:00',
#  '1997-01-01T03:00:00',
#  '1998-01-01T03:00:00',
#  '1999-01-01T03:00:00',
#  '2000-01-01T03:00:00',
#  '2001-01-01T03:00:00',
#  '2002-01-01T03:00:00',
#  '2003-01-01T03:00:00',
#  '2004-01-01T03:00:00',
#  '2005-01-01T03:00:00']

# %%
end_time = list(df_7.end_time.unique())
end_time.sort()
end_time
# Out:
# ['1951-12-30T21:00:00',
#  '1952-12-30T21:00:00',
#  '1953-12-30T21:00:00',
#  '1954-12-30T21:00:00',
#  '1955-12-30T21:00:00',
#  '1956-12-30T21:00:00',
#  '1957-12-30T21:00:00',
#  '1958-12-30T21:00:00',
#  '1959-12-30T21:00:00',
#  '1960-12-30T21:00:00',
#  '1961-12-30T21:00:00',
#  '1962-12-30T21:00:00',
#  '1963-12-30T21:00:00',
#  '1964-12-30T21:00:00',
#  '1965-12-30T21:00:00',
#  '1966-12-30T21:00:00',
#  '1967-12-30T21:00:00',
#  '1968-12-30T21:00:00',
#  '1969-12-30T21:00:00',
#  '1970-12-30T21:00:00',
#  '1971-12-30T21:00:00',
#  '1972-12-30T21:00:00',
#  '1973-12-30T21:00:00',
#  '1974-12-30T21:00:00',
#  '1975-12-30T21:00:00',
#  '1976-12-30T21:00:00',
#  '1977-12-30T21:00:00',
#  '1978-12-30T21:00:00',
#  '1979-12-30T21:00:00',
#  '1980-12-30T21:00:00',
#  '1981-12-30T21:00:00',
#  '1982-12-30T21:00:00',
#  '1983-12-30T21:00:00',
#  '1984-12-30T21:00:00',
#  '1985-12-30T21:00:00',
#  '1986-12-30T21:00:00',
#  '1987-12-30T21:00:00',
#  '1988-12-30T21:00:00',
#  '1989-12-30T21:00:00',
#  '1990-12-30T21:00:00',
#  '1991-12-30T21:00:00',
#  '1992-12-30T21:00:00',
#  '1993-12-30T21:00:00',
#  '1994-12-30T21:00:00',
#  '1995-12-30T21:00:00',
#  '1996-12-30T21:00:00',
#  '1997-12-30T21:00:00',
#  '1998-12-30T21:00:00',
#  '1999-12-30T21:00:00',
#  '2000-12-30T21:00:00',
#  '2001-12-30T21:00:00',
#  '2002-12-30T21:00:00',
#  '2003-12-30T21:00:00',
#  '2004-12-30T21:00:00',
#  '2005-11-30T21:00:00']

# %%
list(df_7.path.unique())[0:5]
# Out:
# ['output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1951120103-1951123021.nc',
#  'output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1952010103-1952123021.nc',
#  'output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1953010103-1953123021.nc',
#  'output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1954010103-1954123021.nc',
#  'output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1955010103-1955123021.nc']

# %% [markdown]
# ### check on disk
#
# ```
# du -sh output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/*
#
# 25M     output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1951120103-1951123021.nc
# 198M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1952010103-1952123021.nc
# 196M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1953010103-1953123021.nc
# 198M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1954010103-1954123021.nc
# 201M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1955010103-1955123021.nc
# 200M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1956010103-1956123021.nc
# 200M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1957010103-1957123021.nc
# 201M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1958010103-1958123021.nc
# 198M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1959010103-1959123021.nc
# 195M    output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1960010103-1960123021.nc
# ```

# %% [markdown]
# ### Get netcdf with rooki

# %%
resp = rooki.subset(
    collection=ds_id_7,
    time='1950/1951',
)
resp.ok
# Out:
# True

# %%
resp.download_urls()
# Out:
# ['https://data.mips.climate.copernicus.eu/thredds/fileServer/esg_c3s-cordex/output/EUR-11/MOHC/MOHC-HadGEM2-ES/historical/r1i1p1/MOHC-HadREM3-GA7-05/v1/6hr/mrro/v20200330/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1951120103-1951123021.nc']

# %%
dsets = resp.datasets()
# Out:
# Downloading to /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/metalink_pvfmw7sd/mrro_EUR-11_MOHC-HadGEM2-ES_historical_r1i1p1_MOHC-HadREM3-GA7-05_v1_6hr_1951120103-1951123021.nc.

# %%
ds = dsets[0]
ds
# Out:
# <xarray.Dataset> Size: 98MB
# Dimensions:                     (rlat: 412, rlon: 424, time: 120, bnds: 2,
#                                  vertices: 4)
# Coordinates:
#     latitude                    (rlat, rlon) float64 1MB ...
#     longitude                   (rlat, rlon) float64 1MB ...
#   * rlat                        (rlat) float64 3kB -23.37 -23.26 ... 21.73 21.84
#   * rlon                        (rlon) float64 3kB -28.38 -28.27 ... 18.04 18.15
#   * time                        (time) object 960B 1951-12-01 03:00:00 ... 19...
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     mrro                        (time, rlat, rlon) float32 84MB ...
#     rlat_bnds                   (rlat, bnds) float64 7kB ...
#     rlon_bnds                   (rlon, bnds) float64 7kB ...
#     rotated_latitude_longitude  int32 4B ...
#     time_bnds                   (time, bnds) object 2kB ...
#     vertices_latitude           (rlat, rlon, vertices) float64 6MB ...
#     vertices_longitude          (rlat, rlon, vertices) float64 6MB ...
# Attributes: (12/22)
#     model_id:                       MOHC-HadREM3-GA7-05
#     driving_experiment_name:        historical
#     creation_date:                  2020-01-30T12:55:29Z
#     project_id:                     CORDEX
#     experiment:                     historical run using HadGEM2-ES as drivin...
#     institution:                    MetOffice, Hadley Centre, UK
#     ...                             ...
#     driving_model_id:               MOHC-HadGEM2-ES
#     institute_id:                   MOHC
#     frequency:                      6hr
#     history:                        Thu Mar 26 11:22:48 2020: ncatted -O -a t...
#     NCO:                            4.7.3
#     tracking_id:                    hdl:21.14103/545b09bc-1aee-4c77-93c9-2785...
