# %% [markdown]
# # issue with atlas data request
#
# date: 2026-04-20
#
#
# An atlas request shows the error: `is_file check failed. reason=[Errno 36] File name too long`
#
# The slurm job seems to keep running ... but for 20 minutes.

# %% [markdown]
# request:
#
# ```
# {\\\"inputs\\\": {\\\"\\\": [\\\"c3s-cica-atlas.r.CMIP5.rcp45.mon.v2\\\"], \\\"tas\\\": [\\\"c3s-cmip6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.r1i1p1f2.Amon.tas.gr.v20190219\\\"], \\\"sfcWind\\\": [\\\"c3s-cmip6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp585.r1i1p1f3.Amon.sfcWind.gn.v20200114\\\"], \\\"tasmax\\\": [\\\"c3s-cmip6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.day.tasmax.gn.v20191016\\\"]}, \\\"steps\\\": {\\\"subset__1\\\": {\\\"run\\\": \\\"subset\\\", \\\"in\\\": {\\\"collection\\\": \\\"inputs/\\\", \\\"area\\\": \\\"76.5,8,80.5,14\\\"}}, \\\"subset_tas_1\\\": {\\\"run\\\": \\\"subset\\\", \\\"in\\\": {\\\"collection\\\": \\\"inputs/tas\\\", \\\"time_components\\\": \\\"month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec|year:2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050\\\", \\\"time\\\": \\\"2026/2050\\\"}}, \\\"subset_sfcWind_1\\\": {\\\"run\\\": \\\"subset\\\", \\\"in\\\": {\\\"collection\\\": \\\"inputs/sfcWind\\\", \\\"time_components\\\": \\\"month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec|year:2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050\\\", \\\"time\\\": \\\"2026/2050\\\"}}, \\\"subset_tasmax_1\\\": {\\\"run\\\": \\\"subset\\\", \\\"in\\\": {\\\"collection\\\": \\\"inputs/tasmax\\\", \\\"area\\\": \\\"73,3,136,54\\\", \\\"time_components\\\": \\\"month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec|year:1850,1851,1852,1853,1854,1855,1856,1857,1858,1859,1860,1861,1862,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014\\\", \\\"time\\\": \\\"1850/2014\\\"}}}, \\\"outputs\\\": {\\\"output\\\": \\\"subset_tasmax_1/output\\\"}
# ```

# %% [markdown]
# error:
# ```
# is_file check failed. reason=[Errno 36] File name too long: '{"inputs": {"": ["c3s-cica-atlas.r.CMIP5.rcp45.mon.v2"], "tas": ["c3s-cmip6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.r1i1p1f2.Amon.tas.gr.v20190219"], "sfcWind": ["c3s-cmip6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp585.r1i1p1f3.Amon.sfcWind.gn.v20200114"], "tasmax": ["c3s-cmip6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.day.tasmax.gn.v20191016"]}, "steps": {"subset__1": {"run": "subset", "in": {"collection": "inputs/", "area": "76.5,8,80.5,14"}}, "subset_tas_1": {"run": "subset", "in": {"collection": "inputs/tas", "time_components": "month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec|year:2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050", "time": "2026/2050"}}, "subset_sfcWind_1": {"run": "subset", "in": {"collection": "inputs/sfcWind", "time_components": "month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec|year:2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050", "time": "2026/2050"}}, "subset_tasmax_1": {"run": "subset", "in": {"collection": "inputs/tasmax", "area": "73,3,136,54", "time_components": "month:jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec|year:1850,1851,1852,1853,1854,1855,1856,1857,1858,1859,1860,1861,1862,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014", "time": "1850/2014"}}}, "outputs": {"output": "subset_tasmax_1/output"}, "doc": "workflow"}'
# ```

# %% [markdown]
# provenance:
#
# ```
# {"prefix": {"roocs": "urn:roocs:", "provone": "https://purl.dataone.org/provone/2015/01/15/ontology#", "dcterms": "http://purl.org/dc/terms/"}, "agent": {"roocs:C3S_CDS": {"prov:type": {"$": "prov:Organization", "type": "prov:QUALIFIED_NAME"}, "prov:label": "Copernicus Climate Data Store", "dcterms:source": "https://cds.climate.copernicus.eu"}, "roocs:Provider": {"prov:type": {"$": "prov:Agent", "type": "prov:QUALIFIED_NAME"}, "prov:label": "Provider", "dcterms:source": "Rook"}, "roocs:rook_v0.17.1": {"prov:type": {"$": "prov:SoftwareAgent", "type": "prov:QUALIFIED_NAME"}, "prov:label": "Rook", "dcterms:source": "https://github.com/roocs/rook/releases/tag/v0.17.1"}, "roocs:clisops_v0.16.1": {"prov:type": {"$": "prov:SoftwareAgent", "type": "prov:QUALIFIED_NAME"}, "prov:label": "clisops", "dcterms:source": "https://github.com/roocs/clisops/releases/tag/v0.16.1"}}, "wasAttributedTo": {"_:id1": {"prov:entity": "roocs:rook_v0.17.1", "prov:agent": "roocs:C3S_CDS"}, "_:id2": {"prov:entity": "roocs:rook_v0.17.1", "prov:agent": "roocs:Provider"}}, "entity": {"roocs:workflow_84654453-6112-4a19-a3bf-b0b2bb5d6ea3": {"prov:type": {"$": "provone:Workflow", "type": "prov:QUALIFIED_NAME"}}, "roocs:c3s-cmip6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.day.tasmax.gn.v20191016": {"prov:type": {"$": "provone:Data", "type": "prov:QUALIFIED_NAME"}, "prov:label": "c3s-cmip6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.day.tasmax.gn.v20191016"}, "roocs:tasmax_day_MIROC6_historical_r1i1p1f1_gn_18500101-20141231.nc": {"prov:type": {"$": "provone:Data", "type": "prov:QUALIFIED_NAME"}, "prov:label": "tasmax_day_MIROC6_historical_r1i1p1f1_gn_18500101-20141231.nc"}}, "activity": {"roocs:orchestrate_84654453-6112-4a19-a3bf-b0b2bb5d6ea3": {"prov:type": {"$": "provone:Execution", "type": "prov:QUALIFIED_NAME"}, "prov:label": "orchestrate", "prov:startTime": "2026-04-20T10:10:58", "prov:endTime": "2026-04-20T10:33:32"}, "roocs:subset_tasmax_1_9ac1836c-8ee8-4ec8-b18d-08521bf09885": {"prov:type": {"$": "provone:Execution", "type": "prov:QUALIFIED_NAME"}, "prov:label": "subset_tasmax_1", "roocs:time": "1850/2014", "roocs:time_components": "year:1850,1851,1852,1853,1854,1855,1856,1857,1858,1859,1860,1861,1862,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014", "roocs:area": "73,3,136,54", "roocs:apply_fixes": false}}, "wasAssociatedWith": {"_:id3": {"prov:activity": "roocs:orchestrate_84654453-6112-4a19-a3bf-b0b2bb5d6ea3", "prov:agent": "roocs:rook_v0.17.1", "prov:plan": "roocs:workflow_84654453-6112-4a19-a3bf-b0b2bb5d6ea3"}, "_:id4": {"prov:activity": "roocs:subset_tasmax_1_9ac1836c-8ee8-4ec8-b18d-08521bf09885", "prov:agent": "roocs:clisops_v0.16.1", "prov:plan": "roocs:workflow_84654453-6112-4a19-a3bf-b0b2bb5d6ea3"}}, "wasDerivedFrom": {"_:id5": {"prov:generatedEntity": "roocs:tasmax_day_MIROC6_historical_r1i1p1f1_gn_18500101-20141231.nc", "prov:usedEntity": "roocs:c3s-cmip6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.day.tasmax.gn.v20191016", "prov:activity": "roocs:subset_tasmax_1_9ac1836c-8ee8-4ec8-b18d-08521bf09885"}}}
# ```
