# %% [markdown]
# # CMIP6 daily precipitation non-monotonic time error
#
# When: 2026-08-24
#
# This notebook reproduces a reported CDS WPS error while subsetting daily precipitation (`pr`) from 42 CMIP6 historical datasets for 1970–1989 over the area `88.5,20,93,24`. The request explicitly selects every day, month, and year in the time range.
#
# The service returns: `Process error: Resulting object does not have monotonic global indexes along dimension time`.
#
# The notebook preserves the decoded JSON workflow from the WPS `ComplexData` payload and does not download or open any result data.

# %% [markdown]
# ## Original WPS workflow
#
# The `ComplexData` CDATA contains the following JSON request. The complete `time_components` value is assembled programmatically to keep it readable while retaining the exact request semantics.

# %%
collection = [
    "c3s-cmip6.CMIP.AS-RCEC.TaiESM1.historical.r1i1p1f1.day.pr.gn.v20200626",
    "c3s-cmip6.CMIP.AWI.AWI-ESM-1-1-LR.historical.r1i1p1f1.day.pr.gn.v20200212",
    "c3s-cmip6.CMIP.BCC.BCC-CSM2-MR.historical.r2i1p1f1.day.pr.gn.v20181116",
    "c3s-cmip6.CMIP.BCC.BCC-ESM1.historical.r1i1p1f1.day.pr.gn.v20181220",
    "c3s-cmip6.CMIP.CAS.FGOALS-f3-L.historical.r1i1p1f1.day.pr.gr.v20191019",
    "c3s-cmip6.CMIP.CAS.FGOALS-g3.historical.r1i1p1f1.day.pr.gn.v20190826",
    "c3s-cmip6.CMIP.CCCR-IITM.IITM-ESM.historical.r1i1p1f1.day.pr.gn.v20191226",
    "c3s-cmip6.CMIP.CCCma.CanESM5.historical.r1i1p1f1.day.pr.gn.v20190429",
    "c3s-cmip6.CMIP.CMCC.CMCC-CM2-HR4.historical.r1i1p1f1.day.pr.gn.v20200904",
    "c3s-cmip6.CMIP.CMCC.CMCC-CM2-SR5.historical.r1i1p1f1.day.pr.gn.v20200616",
    "c3s-cmip6.CMIP.CMCC.CMCC-ESM2.historical.r1i1p1f1.day.pr.gn.v20210114",
    "c3s-cmip6.CMIP.CNRM-CERFACS.CNRM-CM6-1-HR.historical.r1i1p1f2.day.pr.gr.v20191021",
    "c3s-cmip6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r1i1p1f2.day.pr.gr.v20180917",
    "c3s-cmip6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.r1i1p1f2.day.pr.gr.v20181206",
    "c3s-cmip6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r1i1p1f1.day.pr.gn.v20191108",
    "c3s-cmip6.CMIP.CSIRO.ACCESS-ESM1-5.historical.r1i1p1f1.day.pr.gn.v20191115",
    "c3s-cmip6.CMIP.EC-Earth-Consortium.EC-Earth3-AerChem.historical.r1i1p1f1.day.pr.gr.v20200624",
    "c3s-cmip6.CMIP.EC-Earth-Consortium.EC-Earth3-CC.historical.r1i1p1f1.day.pr.gr.v20210113",
    "c3s-cmip6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical.r1i1p1f1.day.pr.gr.v20200217",
    "c3s-cmip6.CMIP.INM.INM-CM4-8.historical.r1i1p1f1.day.pr.gr1.v20190530",
    "c3s-cmip6.CMIP.INM.INM-CM5-0.historical.r1i1p1f1.day.pr.gr1.v20190610",
    "c3s-cmip6.CMIP.IPSL.IPSL-CM5A2-INCA.historical.r1i1p1f1.day.pr.gr.v20200729",
    "c3s-cmip6.CMIP.IPSL.IPSL-CM6A-LR.historical.r1i1p1f1.day.pr.gr.v20180803",
    "c3s-cmip6.CMIP.KIOST.KIOST-ESM.historical.r1i1p1f1.day.pr.gr1.v20191202",
    "c3s-cmip6.CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.day.pr.gn.v20191129",
    "c3s-cmip6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.day.pr.gn.v20191016",
    "c3s-cmip6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r1i1p1f3.day.pr.gn.v20190624",
    "c3s-cmip6.CMIP.MOHC.HadGEM3-GC31-MM.historical.r1i1p1f3.day.pr.gn.v20191207",
    "c3s-cmip6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.day.pr.gn.v20190627",
    "c3s-cmip6.CMIP.MPI-M.MPI-ESM1-2-HR.historical.r1i1p1f1.day.pr.gn.v20190710",
    "c3s-cmip6.CMIP.MPI-M.MPI-ESM1-2-LR.historical.r1i1p1f1.day.pr.gn.v20190710",
    "c3s-cmip6.CMIP.MRI.MRI-ESM2-0.historical.r1i1p1f1.day.pr.gn.v20190603",
    "c3s-cmip6.CMIP.NCAR.CESM2-FV2.historical.r1i1p1f1.day.pr.gn.v20191120",
    "c3s-cmip6.CMIP.NCAR.CESM2-WACCM-FV2.historical.r1i1p1f1.day.pr.gn.v20191120",
    "c3s-cmip6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.day.pr.gn.v20190415",
    "c3s-cmip6.CMIP.NCAR.CESM2.historical.r1i1p1f1.day.pr.gn.v20190401",
    "c3s-cmip6.CMIP.NCC.NorCPM1.historical.r1i1p1f1.day.pr.gn.v20200724",
    "c3s-cmip6.CMIP.NCC.NorESM2-MM.historical.r1i1p1f1.day.pr.gn.v20191108",
    "c3s-cmip6.CMIP.NIMS-KMA.KACE-1-0-G.historical.r1i1p1f1.day.pr.gr.v20190911",
    "c3s-cmip6.CMIP.NOAA-GFDL.GFDL-ESM4.historical.r1i1p1f1.day.pr.gr1.v20190726",
    "c3s-cmip6.CMIP.NUIST.NESM3.historical.r1i1p1f1.day.pr.gn.v20190812",
    "c3s-cmip6.CMIP.SNU.SAM0-UNICON.historical.r1i1p1f1.day.pr.gn.v20190323",
]

days = ",".join(f"{day:02d}" for day in range(1, 32))
months = "jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec"
years = ",".join(str(year) for year in range(1970, 1990))
time_components = f"day:{days}|month:{months}|year:{years}"

request = {
    "inputs": {"pr": collection},
    "steps": {
        "subset_pr_1": {
            "run": "subset",
            "in": {
                "collection": "inputs/pr",
                "area": "88.5,20,93,24",
                "time_components": time_components,
                "time": "1970/1989",
            },
        }
    },
    "outputs": {"output": "subset_pr_1/output"},
    "doc": "workflow",
}

assert len(collection) == 42
request

# %% [markdown]
# ## Build the equivalent Rooki workflow
#
# Importing Rooki contacts the configured WPS service. Change `ROOK_URL` if the reproduction should run against another deployment.

# %%
import json
import os

os.environ["ROOK_URL"] = "http://rook.dkrz.de/wps"

from rooki import operators as ops

# %%
pr = ops.Input("pr", request["inputs"]["pr"])
subset = ops.Subset(
    pr,
    area=request["steps"]["subset_pr_1"]["in"]["area"],
    time=request["steps"]["subset_pr_1"]["in"]["time"],
    time_components=request["steps"]["subset_pr_1"]["in"]["time_components"],
)

serialized_request = json.loads(subset._serialise())
assert serialized_request == request
serialized_request

# %% [markdown]
# ## Reproduce the error
#
# The next cell submits the full 42-dataset request. It is disabled by default because it may be expensive or trigger the reported server-side error. Set `RUN_REQUEST` to `True` only against the deployment being tested.

# %%
from time import perf_counter

RUN_REQUEST = False

if RUN_REQUEST:
    started_at = perf_counter()
    resp = subset.orchestrate()
    elapsed_seconds = perf_counter() - started_at
    print(f"Orchestration time: {elapsed_seconds:.1f} seconds")
    print(f"Succeeded: {resp.ok}")
    print(f"Status: {resp.status}")
    display(resp)
else:
    print("Request not submitted; set RUN_REQUEST = True to reproduce the error.")

# %% [markdown]
# ## Observed failure
#
# The WPS response contains the following exception:
#
# ```xml
# <ows:ExceptionText>Process error: Resulting object does not have monotonic global indexes along dimension time</ows:ExceptionText>
# ```
#
# This error is raised while combining files when their decoded `time` coordinates cannot form one globally monotonic index. Possible data-level causes include overlapping or duplicate timestamps, files supplied out of temporal order, or inconsistent time encodings/calendars. The message alone does not identify which of the 42 datasets causes the failure. Running the same subset for each dataset separately is the most direct way to isolate the problematic collection before inspecting its source-file time coordinates.

# %% [markdown]
# ## Inspect a successful response without loading data
#
# If the workflow succeeds, inspect the Metalink size and output URLs without downloading or opening the NetCDF results.

# %%
if RUN_REQUEST and resp.ok:
    print(
        f"Total output size from Metalink: {resp.size:,} bytes "
        f"({resp.size_in_mb:.2f} MiB / {resp.size_in_gb:.3f} GiB)"
    )
    print("\nOutput URLs (not downloaded):")
    for url in resp.download_urls():
        print(url)
