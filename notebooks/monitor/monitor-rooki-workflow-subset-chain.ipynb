# %% [markdown]
# # Test rook workflow with subset chain

# %%
from rooki import operators as ops

# %%
wf = ops.Subset(
        ops.Subset(
            ops.Input(
                'tas', ['c3s-cmip5.output1.ICHEC.EC-EARTH.historical.day.atmos.day.r1i1p1.tas.latest']
            ),
            time="1860-01-01/1920-12-30",
        ),
        time="1880-01-01/1900-12-30",
)

# %%
result = wf.orchestrate()
result
# Out:
# Metalink URL: http://cp4cds-cn1.dkrz.de:80/outputs/rook/f4c3283a-f68e-11ea-ad1f-f2e4655a10b7/input.meta4, size: 1197432 bytes, num files: 1

# %%
result.download_urls()[0]
# Out:
# 'http://cp4cds-cn1.dkrz.de:80/outputs/rook/fa343232-f68e-11ea-ad1f-f2e4655a10b7/lon_bounds_day_EC-EARTH_historical_r1i1p1_18800101-19001229.nc'
