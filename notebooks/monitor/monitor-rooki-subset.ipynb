# %% [markdown]
# # Test subset Operation

# %%
from rooki import rooki

# %%
result = rooki.subset(
    collection='c3s-cmip5.output1.ICHEC.EC-EARTH.historical.day.atmos.day.r1i1p1.tas.latest',
    time='1860-01-01/1900-12-30',
)
result
# Out:
# Metalink URL: http://cp4cds-cn1.dkrz.de:80/outputs/rook/00b67f5c-f68f-11ea-ad1f-f2e4655a10b7/input.meta4, size: 2307799 bytes, num files: 1

# %%
result.download_urls()[0]
# Out:
# 'http://cp4cds-cn1.dkrz.de:80/outputs/rook/04508cd4-f68f-11ea-ad1f-f2e4655a10b7/lon_bounds_day_EC-EARTH_historical_r1i1p1_18600101-19001229.nc'
