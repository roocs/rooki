# %% [markdown]
# # Performance of concat operator on cmip6 decadal
#
# **Rooki** calls climate data operations on the **rook** processing service.

# %%
import os
import time
os.environ['ROOK_URL'] = 'http://rook.dkrz.de/wps'

from rooki import operators as ops

# %% [markdown]
# ## Load intake catalog for cmip6 decadal

# %%
import intake

# %%
cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/master/intake/catalogs/c3s.yaml"

cat = intake.open_catalog(cat_url)
df_cmip6_decadal = cat['c3s-cmip6-decadal'].read()
df_cmip6_decadal.head()
# Out:
# /usr/local/Caskroom/mambaforge/base/envs/rooki/lib/python3.11/site-packages/dask/dataframe/io/csv.py:542: UserWarning: Warning gzip compression does not support breaking apart files
# Please ensure that each individual file can fit in memory and
# use the keyword ``blocksize=None to remove this message``
# Setting ``blocksize=None``
#   warn(
#                                                ds_id
# 0  c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...  \
# 1  c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 2  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 3  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 4  c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
#
#                                                 path       size
# 0  DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2016-...  492479692  \
# 1  DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2009-...  737204109
# 2  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1987...     953384
# 3  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1995...     603757
# 4  DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s2004...   14824913
#
#              mip_era activity_id institution_id        source_id
# 0  c3s-cmip6-decadal        DCPP          MPI-M    MPI-ESM1-2-HR  \
# 1  c3s-cmip6-decadal        DCPP          MPI-M    MPI-ESM1-2-HR
# 2  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 3  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
# 4  c3s-cmip6-decadal        DCPP           MOHC  HadGEM3-GC31-MM
#
#     experiment_id        member_id table_id variable_id grid_label    version
# 0  dcppA-hindcast   s2016-r8i1p1f1      day      tasmax         gn  v20210111  \
# 1  dcppA-hindcast   s2009-r8i1p1f1      day          pr         gn  v20210107
# 2  dcppA-hindcast   s1987-r3i1p1f2     Amon          pr         gn  v20200417
# 3  dcppA-hindcast   s1995-r6i1p1f2     Amon         tas         gn  v20200417
# 4  dcppA-hindcast  s2004-r10i1p1f2   AERday       zg500         gn  v20200417
#
#             start_time             end_time                         bbox
# 0  2016-11-01T12:00:00  2026-12-31T12:00:00  0.00, -89.28, 359.06, 89.28  \
# 1  2009-11-01T12:00:00  2019-12-31T12:00:00  0.00, -89.28, 359.06, 89.28
# 2  1987-11-16T00:00:00  1987-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 3  1995-11-16T00:00:00  1995-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 4  2004-11-01T12:00:00  2004-12-30T12:00:00  0.42, -89.72, 359.58, 89.72
#
#       level member_year member_ensemble             prefix
# 0      2.00       s2016        r8i1p1f1  c3s-cmip6-decadal
# 1       NaN       s2009        r8i1p1f1  c3s-cmip6-decadal
# 2       NaN       s1987        r3i1p1f2  c3s-cmip6-decadal
# 3      1.50       s1995        r6i1p1f2  c3s-cmip6-decadal
# 4  50000.00       s2004       r10i1p1f2  c3s-cmip6-decadal

# %%
df = df_cmip6_decadal.loc[
    (df_cmip6_decadal.variable_id=="pr") 
    & (df_cmip6_decadal.experiment_id=="dcppB-forecast")
    & (df_cmip6_decadal.table_id=="day")
    & (df_cmip6_decadal.institution_id=="EC-Earth-Consortium")
    & (df_cmip6_decadal.member_year=="s2019")
]
dsets = list(df.ds_id.unique())
dsets
# Out:
# ['c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r10i1p1f1.day.pr.gr.v20210121',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r9i1p1f1.day.pr.gr.v20210121',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r5i1p1f1.day.pr.gr.v20210120',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r8i1p1f1.day.pr.gr.v20210121',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r1i1p1f1.day.pr.gr.v20210120',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r6i1p1f1.day.pr.gr.v20210120',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r4i1p1f1.day.pr.gr.v20210120',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r2i1p1f1.day.pr.gr.v20210121',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r7i1p1f1.day.pr.gr.v20210120',
#  'c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-Earth3.dcppB-forecast.s2019-r3i1p1f1.day.pr.gr.v20210120']

# %% [markdown]
# ## Run concat
#
# https://docs.xarray.dev/en/stable/generated/xarray.concat.html

# %%
start = time.time()

t = "2020-12-01/2020-12-31" 

wf = ops.Concat(
        ops.Input('ds', dsets),
        time=t,
        dims="realization"
)

# optional average
wf = ops.Average(wf, dims="realization")

# optional subset
wf = ops.Subset(wf, time=t, time_components="month:dec")

resp = wf.orchestrate()

end = time.time()
print(f"duration: {int(end - start)} secs")
print(resp)

resp.ok
# Out:
# duration: 34 secs
# Metalink URL: http://rook4.cloud.dkrz.de:80/outputs/rook/c779629e-104f-11ee-b844-fa163ed6c06f/input.meta4, num files: 1
# True

# %% [markdown]
# **open with xarray**

# %%
resp.size_in_mb
# Out:
# 15.550009727478027

# %%
resp.download_urls()
# Out:
# ['http://rook4.cloud.dkrz.de:80/outputs/rook/da87c588-104f-11ee-8706-fa163ed6c06f/pr_day_EC-Earth3_dcppB-forecast_r10i1p1f1_gr_20201201-20201231.nc']

# %%
dsets = resp.datasets()
# Out:
# Downloading to /var/folders/qb/mg0csz190wd4rxybhhnwjln80000gn/T/metalink_3d87fzyo/pr_day_EC-Earth3_dcppB-forecast_r10i1p1f1_gr_20201201-20201231.nc.

# %%
ds = dsets[0]
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 31, lat: 256, bnds: 2, lon: 512)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-12-01T12:00:00 ... 2020-12-31T12:...
#   * lat          (lat) float64 -89.46 -88.77 -88.07 -87.37 ... 88.07 88.77 89.46
#   * lon          (lon) float64 0.3516 1.055 1.758 2.461 ... 358.2 358.9 359.6
#     reftime      datetime64[ns] ...
#     leadtime     (time) timedelta64[ns] ...
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds     (lat, bnds) float64 ...
#     lon_bnds     (lon, bnds) float64 ...
#     pr           (time, lat, lon) float32 ...
#     realization  float64 ...
# Attributes: (12/52)
#     Conventions:                 CF-1.7 CMIP-6.2
#     activity_id:                 DCPP
#     branch_method:               no parent
#     branch_time:                 0.0
#     branch_time_in_child:        0.0
#     branch_time_in_parent:       0.0
#     ...                          ...
#     cmor_version:                3.4.0
#     nominal_resolution:          100 km
#     forcing_description:         f1, CMIP6 historical forcings
#     physics_description:         physics from the standard model configuratio...
#     initialization_description:  Atmosphere initialization based on full-fiel...
#     startdate:                   s201911

# %% [markdown]
# **provenance**

# %%
prov_plot_url = resp.provenance_image()
prov_plot_url
# Out:
# 'http://rook4.cloud.dkrz.de:80/outputs/rook/c779629e-104f-11ee-b844-fa163ed6c06f/provenance.png'

# %%
# from IPython.display import Image
# Image(prov_plot_url)

# %%
resp.provenance()
# Out:
# 'http://rook4.cloud.dkrz.de:80/outputs/rook/c779629e-104f-11ee-b844-fa163ed6c06f/provenance.json'
